# %%
# Aminu Hashim, CFSN, MNIFST
### Food Scientist | Data & Monitoring, Evaluation and Learning (MEL) | Food Safety & Quality

#I am building skills at the intersection of food science, data analysis, and development research.


print("hello, data science")
# Out:
# hello, data science
